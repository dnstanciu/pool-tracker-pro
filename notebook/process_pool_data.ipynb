# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
# Load data from CSV
data = pd.read_csv("./data/pool_data.csv")

# %%
data.head()
# Out:
#    Unnamed: 0       Frame_Index  Area  Mean  Radius
# 0           0  frame_000278.png   0.0   0.0     0.0
# 1           1  frame_000279.png   0.0   0.0     0.0
# 2           2  frame_000280.png   0.0   0.0     0.0
# 3           3  frame_000281.png   0.0   0.0     0.0
# 4           4  frame_000282.png   0.0   0.0     0.0

# %%
data
# Out:
#     Unnamed: 0       Frame_Index   Area        Mean     Radius
# 0            0  frame_000278.png    0.0    0.000000   0.000000
# 1            1  frame_000279.png    0.0    0.000000   0.000000
# 2            2  frame_000280.png    0.0    0.000000   0.000000
# 3            3  frame_000281.png    0.0    0.000000   0.000000
# 4            4  frame_000282.png    0.0    0.000000   0.000000
# 5            5  frame_000283.png    0.0    0.000000   0.000000
# 6            6  frame_000284.png    0.0    0.000000   0.000000
# 7            7  frame_000285.png  968.0  216.358974  40.305187
# 8            8  frame_000286.png  968.0  216.358974  40.305187
# 9            9  frame_000287.png    0.0    0.000000   0.000000
# 10          10  frame_000288.png    0.0    0.000000   0.000000
# 11          11  frame_000289.png    0.0    0.000000   0.000000
# 12          12  frame_000290.png    0.0    0.000000   0.000000
# 13          13  frame_000291.png    0.0    0.000000   0.000000
# 14          14  frame_000292.png    0.0    0.000000   0.000000
# 15          15  frame_000293.png    0.0    0.000000   0.000000
# 16          16  frame_000294.png    0.0    0.000000   0.000000
# 17          17  frame_000295.png    0.0    0.000000   0.000000
# 18          18  frame_000296.png    0.0    0.000000   0.000000
# 19          19  frame_000297.png    0.0    0.000000   0.000000
# 20          20  frame_000298.png    0.0    0.000000   0.000000
# 21          21  frame_000299.png    0.0    0.000000   0.000000
# 22          22  frame_000300.png    0.0    0.000000   0.000000
# 23          23  frame_000301.png    0.0    0.000000   0.000000
# 24          24  frame_000302.png    0.0    0.000000   0.000000
# 25          25  frame_000303.png    0.0    0.000000   0.000000
# 26          26  frame_000304.png    0.0    0.000000   0.000000
# 27          27  frame_000305.png    0.0    0.000000   0.000000
# 28          28  frame_000306.png    0.0    0.000000   0.000000
# 29          29  frame_000307.png    0.0    0.000000   0.000000
# 30          30  frame_000308.png    0.0    0.000000   0.000000

# %%
data.plot

# %%
cols_plot = ['Area', 'Mean', 'Radius']
axes = data[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
